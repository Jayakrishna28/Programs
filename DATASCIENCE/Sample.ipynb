# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
np.arange(10)
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
d2=pd.read_csv("C:/Users/LENOVO/OneDrive/Documents/CODING/homeprices.csv")
d2
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Scatter Plot")
plt.scatter(d2.area,d2.price,color="green")

# %%
reg=linear_model.LinearRegression()
reg.fit(d2[['area']],d2.price)
# Out:
# LinearRegression()

# %%
reg.predict([[2600]])
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([533664.38356164])

# %%
reg.predict(d1)
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])
