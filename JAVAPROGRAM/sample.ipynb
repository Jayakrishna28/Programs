# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB 960.0 kB/s eta 0:00:12
#    ---------------------------------------- 0.1/11.5 MB 919.0 kB/s eta 0:00:13
#     --------------------------------------- 0.2/11.5 MB 1.2 MB/s eta 0:00:10
#     --------------------------------------- 0.2/11.5 MB 1.2 MB/s eta 0:00:10
#     --------------------------------------- 0.2/11.5 MB 1.2 MB/s eta 0:00:10
#    - -------------------------------------- 0.3/11.5 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.3/11.5 MB 1.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/11.5 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/11.5 MB 1.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/11.5 MB 1.1 MB/s eta 0:00:10
#    -- ------------------------------------- 0.6/11.5 MB 1.2 MB/s eta 0:00:10
# ...

# %%
python.exe -m pip install --upgrade pip
# Out:
#   Cell In[2], line 1
#     python.exe -m pip install --upgrade pip
#                   ^
# SyntaxError: invalid syntax

# %%
import numpy as np
np.arange(25)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\venv\Lib\site-packages\numpy\core\__init__.py:24
#      23 try:
# ---> 24     from . import multiarray
#      25 except ImportError as exc:
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\venv\Lib\site-packages\numpy\core\multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\venv\Lib\site-packages\numpy\core\overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy.core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'
#
# ...
